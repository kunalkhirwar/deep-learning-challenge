# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df[[col for col in application_df.columns if col not in ['EIN', 'NAME']]]
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 500
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts[classification_counts > 1])
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 800
classifications_to_replace = classification_counts[classification_counts <800].index.to_list()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies_df = pd.get_dummies(application_df[['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
       'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS', 'ASK_AMT', 'IS_SUCCESSFUL']])
application_dummies_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummies_df['IS_SUCCESSFUL']
X = application_dummies_df[[col for col in application_dummies_df.columns if col != "IS_SUCCESSFUL"]]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = 80, activation = 'relu', input_dim = 43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = 30, activation = 'relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5722 - accuracy: 0.7208
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5557 - accuracy: 0.7307
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7323
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7325
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5491 - accuracy: 0.7322
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5481 - accuracy: 0.7348
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7349
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7345
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5467 - accuracy: 0.7342
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5452 - accuracy: 0.7356
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7359
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7363
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5447 - accuracy: 0.7355
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5445 - accuracy: 0.7362
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7358
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7367
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7365
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7363
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7364
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7370
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7369
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.7374
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5415 - accuracy: 0.7372
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5419 - accuracy: 0.7357
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5416 - accuracy: 0.7376
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7383
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7380
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7381
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5404 - accuracy: 0.7385
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7378
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7385
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5404 - accuracy: 0.7382
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5395 - accuracy: 0.7394
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7391
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7391
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7400
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7390
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7394
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7402
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7391
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5386 - accuracy: 0.7402
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7398
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7409
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7395
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7399
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7396
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7388
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7409
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7388
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7405
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7394
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7411
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7402
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7404
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7400
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7401
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7393
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7402
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5370 - accuracy: 0.7400
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7404
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7405
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7403
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7400
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7408
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7411
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7414
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7416
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7411
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7409
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7406
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7411
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7412
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7418
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7408
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7407
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7415
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7414
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7416
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7413
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7413
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7409
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7413
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7411
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7418
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7414
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7418
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7407
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7413
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7416
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7421
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7413
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7423
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7408
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7423
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7415
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7416
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7423
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7424
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7417
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7420

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5604 - accuracy: 0.7247 - 454ms/epoch - 2ms/step
# Loss: 0.5604466795921326, Accuracy: 0.7246647477149963

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## **Optimizing the Model: Attempt 1**

# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh', 'sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=100,
        step=5), activation=activation, input_dim=43))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=100,
            step=5),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2)

# %%
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 60 Complete [00h 00m 36s]
# val_accuracy: 0.7251312136650085
#
# Best val_accuracy So Far: 0.7274635434150696
# Total elapsed time: 00h 17m 10s

# %%
top_hyper = tuner.get_best_hyperparameters(3)
for param in top_hyper:
    print(param.values)
# Out:
# {'activation': 'tanh', 'first_units': 96, 'num_layers': 6, 'units_0': 96, 'units_1': 61, 'units_2': 51, 'units_3': 71, 'units_4': 16, 'units_5': 11, 'tuner/epochs': 20, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
# {'activation': 'tanh', 'first_units': 46, 'num_layers': 5, 'units_0': 16, 'units_1': 11, 'units_2': 21, 'units_3': 91, 'units_4': 91, 'units_5': 56, 'tuner/epochs': 20, 'tuner/initial_epoch': 7, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0012'}
# {'activation': 'tanh', 'first_units': 46, 'num_layers': 5, 'units_0': 16, 'units_1': 11, 'units_2': 21, 'units_3': 91, 'units_4': 91, 'units_5': 56, 'tuner/epochs': 3, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}

# %%
# Evaluate the top 3 models against the test dataset
top_model = tuner.get_best_models(3)
for model in top_model:
    model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5561 - accuracy: 0.7275 - 449ms/epoch - 2ms/step
# Loss: 0.5560965538024902, Accuracy: 0.7274635434150696
# 268/268 - 0s - loss: 0.5544 - accuracy: 0.7273 - 406ms/epoch - 2ms/step
# Loss: 0.5543538331985474, Accuracy: 0.7273469567298889
# 268/268 - 0s - loss: 0.5579 - accuracy: 0.7272 - 416ms/epoch - 2ms/step
# Loss: 0.5578839778900146, Accuracy: 0.7272303104400635

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model1 = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu', 'sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model1.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=100,
        step=5), activation=activation, input_dim=43))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 4)):
        nn_model1.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=100,
            step=5),
            activation=activation))

    nn_model1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model1.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model1

# %%
import keras_tuner as kt
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))

# %%
top_hyper = tuner.get_best_hyperparameters(3)
for param in top_hyper:
    print(param.values)
# Out:
# {'activation': 'tanh', 'first_units': 96, 'num_layers': 6, 'units_0': 96, 'units_1': 61, 'units_2': 51, 'units_3': 71, 'units_4': 16, 'units_5': 11, 'tuner/epochs': 20, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
# {'activation': 'tanh', 'first_units': 46, 'num_layers': 5, 'units_0': 16, 'units_1': 11, 'units_2': 21, 'units_3': 91, 'units_4': 91, 'units_5': 56, 'tuner/epochs': 20, 'tuner/initial_epoch': 7, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0012'}
# {'activation': 'tanh', 'first_units': 46, 'num_layers': 5, 'units_0': 16, 'units_1': 11, 'units_2': 21, 'units_3': 91, 'units_4': 91, 'units_5': 56, 'tuner/epochs': 3, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}

# %%
# Evaluate the top 3 models against the test dataset
top_model = tuner.get_best_models(3)
for model in top_model:
    model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5561 - accuracy: 0.7275 - 470ms/epoch - 2ms/step
# Loss: 0.5560965538024902, Accuracy: 0.7274635434150696
# 268/268 - 0s - loss: 0.5544 - accuracy: 0.7273 - 473ms/epoch - 2ms/step
# Loss: 0.5543538331985474, Accuracy: 0.7273469567298889
# 268/268 - 1s - loss: 0.5579 - accuracy: 0.7272 - 570ms/epoch - 2ms/step
# Loss: 0.5578839778900146, Accuracy: 0.7272303104400635

# %% [markdown]
# ## **Optimizing the Model: Attempt 2**

# %%
# Import the PCA module
from sklearn.decomposition import PCA

# %%
# Instantiate the PCA instance and declare the number of PCA variables
pca=PCA(n_components=25)

# %%
# Fit the PCA model on the transformed credit card DataFrame
application_pca = pca.fit_transform(X)

# Review the first 5 rows of the array of list data
#              0         1         2         3         4         5         6   \
# 0 -2.764199e+06  0.771142  1.518666 -0.026544 -0.415100  0.696864 -0.116069
# 1 -2.660609e+06 -0.488113 -0.069220  0.786821  0.513450  0.546217 -0.752828
# 2 -2.764199e+06  1.904694  0.703090  0.634303 -0.096650 -0.066975  0.324304
# 3 -2.762507e+06  0.002907 -0.763175  0.487983  0.620275 -0.770869 -0.519564
# 4 -2.626609e+06 -0.833628  0.828997 -0.095619  0.543422 -0.204304  0.082417
#
#          7         8         9   ...        15        16        17        18  \
# 0 -0.009996 -0.132543  0.171192  ... -0.143940 -0.024233 -0.047079 -0.394835
# 1  0.054523 -0.128716 -0.134494  ... -0.148514  0.610260  1.074766 -0.098091
# 2  0.040126  0.396111 -0.468182  ...  0.036226  0.001917 -0.019761 -0.018325
# 3  0.057210 -0.171484 -0.025171  ... -0.030190  0.292411  0.028224  0.115920
# 4  0.746656 -0.103676  0.039237  ... -0.009145  0.006656 -0.052114  0.264784
#
#          19        20        21        22        23        24
# 0  0.078058  0.430210 -0.573378 -0.375099 -0.447251 -0.074092
# 1 -0.408135 -0.038779  0.182896  0.165580 -0.216809 -0.365762
# 2  0.008741 -0.025555  0.011076  0.006285  0.016634  0.005530
# 3  0.919744 -0.076351 -0.002288  0.088446 -0.114621  0.017586
# 4 -0.011513  0.482246 -0.051032 -0.311495  0.096195 -0.290770
#
# [5 rows x 25 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummies_df['IS_SUCCESSFUL']
X = application_pca_df

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = 80, activation = 'relu', input_dim = 25))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = 30, activation = 'relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 80)                2080
#
#  dense_8 (Dense)             (None, 30)                2430
#
#  dense_9 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 4541 (17.74 KB)
# Trainable params: 4541 (17.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs = 200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5688 - accuracy: 0.7193
# Epoch 2/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5545 - accuracy: 0.7277
# Epoch 3/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5516 - accuracy: 0.7299
# Epoch 4/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7303
# Epoch 5/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7295
# Epoch 6/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5484 - accuracy: 0.7317
# Epoch 7/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7319
# Epoch 8/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5468 - accuracy: 0.7319
# Epoch 9/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7322
# Epoch 10/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5458 - accuracy: 0.7331
# Epoch 11/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5456 - accuracy: 0.7322
# Epoch 12/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.7329
# Epoch 13/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5450 - accuracy: 0.7336
# Epoch 14/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7324
# Epoch 15/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7332
# Epoch 16/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7335
# Epoch 17/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7352
# Epoch 18/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7339
# Epoch 19/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7357
# Epoch 20/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7347
# Epoch 21/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7355
# Epoch 22/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7338
# Epoch 23/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7341
# Epoch 24/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7361
# Epoch 25/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7347
# Epoch 26/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7359
# Epoch 27/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.7358
# Epoch 28/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5415 - accuracy: 0.7355
# Epoch 29/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5415 - accuracy: 0.7350
# Epoch 30/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7355
# Epoch 31/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7358
# Epoch 32/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7364
# Epoch 33/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7366
# Epoch 34/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5406 - accuracy: 0.7353
# Epoch 35/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7373
# Epoch 36/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.7357
# Epoch 37/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7360
# Epoch 38/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7365
# Epoch 39/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7366
# Epoch 40/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7380
# Epoch 41/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.7369
# Epoch 42/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7366
# Epoch 43/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7367
# Epoch 44/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7374
# Epoch 45/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5395 - accuracy: 0.7370
# Epoch 46/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7374
# Epoch 47/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7376
# Epoch 48/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7371
# Epoch 49/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7365
# Epoch 50/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7376
# Epoch 51/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7381
# Epoch 52/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7371
# Epoch 53/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7364
# Epoch 54/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5386 - accuracy: 0.7377
# Epoch 55/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7368
# Epoch 56/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7375
# Epoch 57/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5386 - accuracy: 0.7371
# Epoch 58/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7376
# Epoch 59/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7378
# Epoch 60/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7390
# Epoch 61/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7384
# Epoch 62/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7375
# Epoch 63/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7377
# Epoch 64/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7380
# Epoch 65/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7389
# Epoch 66/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7375
# Epoch 67/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7370
# Epoch 68/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5379 - accuracy: 0.7382
# Epoch 69/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7389
# Epoch 70/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7376
# Epoch 71/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7383
# Epoch 72/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7388
# Epoch 73/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7385
# Epoch 74/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7376
# Epoch 75/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5371 - accuracy: 0.7390
# Epoch 76/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7392
# Epoch 77/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7387
# Epoch 78/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7389
# Epoch 79/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5370 - accuracy: 0.7393
# Epoch 80/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7385
# Epoch 81/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7388
# Epoch 82/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7393
# Epoch 83/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 84/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7391
# Epoch 85/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7395
# Epoch 86/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7388
# Epoch 87/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7392
# Epoch 88/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7386
# Epoch 89/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7391
# Epoch 90/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7391
# Epoch 91/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7395
# Epoch 92/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5367 - accuracy: 0.7395
# Epoch 93/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7384
# Epoch 94/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7388
# Epoch 95/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7395
# Epoch 96/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7394
# Epoch 97/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7386
# Epoch 98/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7397
# Epoch 99/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7390
# Epoch 100/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7396
# Epoch 101/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7392
# Epoch 102/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7392
# Epoch 103/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7392
# Epoch 104/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7389
# Epoch 105/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7404
# Epoch 106/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7398
# Epoch 107/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7394
# Epoch 108/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7390
# Epoch 109/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7393
# Epoch 110/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7392
# Epoch 111/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7397
# Epoch 112/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7397
# Epoch 113/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7403
# Epoch 114/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7395
# Epoch 115/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7391
# Epoch 116/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7393
# Epoch 117/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7395
# Epoch 118/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7395
# Epoch 119/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7395
# Epoch 120/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7388
# Epoch 121/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7397
# Epoch 122/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7396
# Epoch 123/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7392
# Epoch 124/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7401
# Epoch 125/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7398
# Epoch 126/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7391
# Epoch 127/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7407
# Epoch 128/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7395
# Epoch 129/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7400
# Epoch 130/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7400
# Epoch 131/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7399
# Epoch 132/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7392
# Epoch 133/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7400
# Epoch 134/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7395
# Epoch 135/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7400
# Epoch 136/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7398
# Epoch 137/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7396
# Epoch 138/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7399
# Epoch 139/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7404
# Epoch 140/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7400
# Epoch 141/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7406
# Epoch 142/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7399
# Epoch 143/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5346 - accuracy: 0.7402
# Epoch 144/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7392
# Epoch 145/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7404
# Epoch 146/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7399
# Epoch 147/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7399
# Epoch 148/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7401
# Epoch 149/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7404
# Epoch 150/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7404
# Epoch 151/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7401
# Epoch 152/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7398
# Epoch 153/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7402
# Epoch 154/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7404
# Epoch 155/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7410
# Epoch 156/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7400
# Epoch 157/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7402
# Epoch 158/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7407
# Epoch 159/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7400
# Epoch 160/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7396
# Epoch 161/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7404
# Epoch 162/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7395
# Epoch 163/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7405
# Epoch 164/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7397
# Epoch 165/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7403
# Epoch 166/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7398
# Epoch 167/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7402
# Epoch 168/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7399
# Epoch 169/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7404
# Epoch 170/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7406
# Epoch 171/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7397
# Epoch 172/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7405
# Epoch 173/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7398
# Epoch 174/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7399
# Epoch 175/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7399
# Epoch 176/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7410
# Epoch 177/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7399
# Epoch 178/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7402
# Epoch 179/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7402
# Epoch 180/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7402
# Epoch 181/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7404
# Epoch 182/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7404
# Epoch 183/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7401
# Epoch 184/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7402
# Epoch 185/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7404
# Epoch 186/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.7400
# Epoch 187/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7411
# Epoch 188/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7406
# Epoch 189/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.7408
# Epoch 190/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7403
# Epoch 191/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7397
# Epoch 192/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7407
# Epoch 193/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7406
# Epoch 194/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7410
# Epoch 195/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7399
# Epoch 196/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7412
# Epoch 197/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7406
# Epoch 198/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7404
# Epoch 199/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7402
# Epoch 200/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7409

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5652 - accuracy: 0.7291 - 293ms/epoch - 1ms/step
# Loss: 0.5651530027389526, Accuracy: 0.7290962338447571

# %%
## **Optimizing the Model: Attempt 3**

# %%
# Choose a new cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 700
application_types_to_replace = ['T10', 'T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 2000
classifications_to_replace = classification_counts[classification_counts <2000].index.to_list()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# Other     6062
# C1200     4837
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies_df = pd.get_dummies(application_df[['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
       'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS', 'ASK_AMT', 'IS_SUCCESSFUL']])
application_dummies_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                    True
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                 False                False                False
# 1                 False                 True                False
# 2                 False                False                False
# 3                 False                 True                False
# 4                 False                 True                False
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                 True                False                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 41 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummies_df['IS_SUCCESSFUL']
X = application_dummies_df[[col for col in application_dummies_df.columns if col != "IS_SUCCESSFUL"]]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = 80, activation = 'relu', input_dim = 40))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = 30, activation = 'relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 80)                3280
#
#  dense_17 (Dense)            (None, 30)                2430
#
#  dense_18 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 5741 (22.43 KB)
# Trainable params: 5741 (22.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5733 - accuracy: 0.7189
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5590 - accuracy: 0.7282
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5571 - accuracy: 0.7295
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5545 - accuracy: 0.7296
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5535 - accuracy: 0.7315
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5526 - accuracy: 0.7296
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5518 - accuracy: 0.7307
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5511 - accuracy: 0.7307
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5504 - accuracy: 0.7327
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5502 - accuracy: 0.7325
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5497 - accuracy: 0.7321
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5492 - accuracy: 0.7341
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5488 - accuracy: 0.7337
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5485 - accuracy: 0.7332
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5486 - accuracy: 0.7334
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5482 - accuracy: 0.7322
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5478 - accuracy: 0.7340
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5472 - accuracy: 0.7352
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5471 - accuracy: 0.7345
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7349
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5464 - accuracy: 0.7348
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5459 - accuracy: 0.7337
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5458 - accuracy: 0.7346
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5452 - accuracy: 0.7370
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7360
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.7359
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5448 - accuracy: 0.7358
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5448 - accuracy: 0.7362
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.7369
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5444 - accuracy: 0.7368
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5446 - accuracy: 0.7363
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5441 - accuracy: 0.7368
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5440 - accuracy: 0.7365
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7371
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5441 - accuracy: 0.7354
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7364
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.7364
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5436 - accuracy: 0.7360
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7367
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7369
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7375
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7366
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7374
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7369
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7369
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7366
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7370
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7375
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.7371
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7383
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7365
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5416 - accuracy: 0.7376
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7376
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7377
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5418 - accuracy: 0.7375
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7378
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7383
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7382
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7378
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5415 - accuracy: 0.7379
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5408 - accuracy: 0.7386
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7374
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7378
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7368
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7379
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7387
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.7386
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7381
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5406 - accuracy: 0.7376
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5406 - accuracy: 0.7381
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7386
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7381
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.7380
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7383
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5404 - accuracy: 0.7378
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7386
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7380
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5401 - accuracy: 0.7396
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7390
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7394
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7387
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7387
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7390
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7381
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7386
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7390
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7381
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7385
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7392
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5395 - accuracy: 0.7387
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5395 - accuracy: 0.7387
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5395 - accuracy: 0.7390
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7385
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7386
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7391
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7389
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7388
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7392
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7394
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7387

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5729 - accuracy: 0.7222 - 410ms/epoch - 2ms/step
# Loss: 0.5729462504386902, Accuracy: 0.7222157716751099
